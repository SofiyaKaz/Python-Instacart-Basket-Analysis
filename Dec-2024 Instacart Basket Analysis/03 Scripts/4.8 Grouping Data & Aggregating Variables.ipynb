# %%
# import libraries
import pandas as pd
import numpy as np
import os

# %%
path=r'/Users/sofiakazeko/Jupiter/Dec-2024 Instacart Basket Analysis'

# %%
#3 import the df_ords_prods_merge
ords_prods_merge= pd.read_pickle(os.path.join(path, '02 Data', 'Prepared Data', 'df_ords_prods_merge1.pkl'))

# %%
df = ords_prods_merge[:1000000]

# %%
df.shape
# Out:
# (1000000, 17)

# %%
df.head()
# Out:
#    order_id  user_id  order_number  orders_day_of_week  order_time  \
# 0   2539329        1             1                   2           8
# 1   2539329        1             1                   2           8
# 2   2539329        1             1                   2           8
# 3   2539329        1             1                   2           8
# 4   2539329        1             1                   2           8
#
#    days_since_prior_order  new_customer  product_id  add_to_cart_order  \
# 0                     NaN          True         196                  1
# 1                     NaN          True       14084                  2
# 2                     NaN          True       12427                  3
# 3                     NaN          True       26088                  4
# 4                     NaN          True       26405                  5
#
#    reordered                             product_name  aisle_id  \
# 0          0                                     Soda        77
# ...

# %%
df.groupby('product_name')

# %%
df.groupby('department_id').agg({'order_number': ['mean']})
# Out:
#               order_number
#                       mean
# department_id
# 1                14.800024
# 2                17.091743
# 3                17.913544
# 4                17.893092
# 5                15.214270
# 6                15.382135
# 7                17.694027
# 8                16.458105
# 9                15.957363
# 10               20.091818
# 11               16.482026
# 12               15.615061
# 13               16.484023
# 14               17.524632
# 15               15.691875
# 16               18.014071
# 17               16.150593
# 18               19.602850
# 19               17.631340
# 20               17.138607
# 21               21.956893

# %%
df.groupby('department_id')['order_number'].mean()
# Out:
# department_id
# 1     14.800024
# 2     17.091743
# 3     17.913544
# 4     17.893092
# 5     15.214270
# 6     15.382135
# 7     17.694027
# 8     16.458105
# 9     15.957363
# 10    20.091818
# 11    16.482026
# 12    15.615061
# 13    16.484023
# 14    17.524632
# 15    15.691875
# 16    18.014071
# 17    16.150593
# 18    19.602850
# 19    17.631340
# 20    17.138607
# 21    21.956893
# Name: order_number, dtype: float64

# %%
df.groupby('department_id').agg({'order_number': ['mean', 'min', 'max']})
# Out:
#               order_number
#                       mean min max
# department_id
# 1                14.800024   1  99
# 2                17.091743   1  98
# 3                17.913544   1  99
# 4                17.893092   1  99
# 5                15.214270   1  99
# 6                15.382135   1  99
# 7                17.694027   1  99
# 8                16.458105   1  91
# 9                15.957363   1  99
# 10               20.091818   1  99
# 11               16.482026   1  99
# 12               15.615061   1  99
# 13               16.484023   1  99
# 14               17.524632   1  99
# 15               15.691875   1  99
# 16               18.014071   1  99
# 17               16.150593   1  99
# 18               19.602850   1  99
# 19               17.631340   1  99
# 20               17.138607   1  99
# 21               21.956893   1  97

# %% [markdown]
# # Task - 2.Find the aggregated mean of the “order_number” column grouped by “department_id”

# %%
ords_prods_merge.groupby('department_id').agg({'order_number': ['mean']})
# Out:
#               order_number
#                       mean
# department_id
# 1                15.457838
# 2                17.277920
# 3                17.170395
# 4                17.811403
# 5                15.215751
# 6                16.439806
# 7                17.225802
# 8                15.340650
# 9                15.895474
# 10               20.197148
# 11               16.170638
# 12               15.887671
# 13               16.583536
# 14               16.773669
# 15               16.165037
# 16               17.665606
# 17               15.694469
# 18               19.310397
# 19               17.177343
# 20               16.473447
# 21               22.902379

# %% [markdown]
# The results for the entire dataframe differ from those of the subset for +-1. In general the numbers look very close.

# %% [markdown]
# # 4.creating a loyalty flag for existing customers using the transform() and loc() functions.

# %%
ords_prods_merge['max_order'] = ords_prods_merge.groupby(['user_id'])['order_number'].transform('max')

# %%
ords_prods_merge.head()
# Out:
#    order_id  user_id  order_number  orders_day_of_week  order_time  \
# 0   2539329        1             1                   2           8
# 1   2539329        1             1                   2           8
# 2   2539329        1             1                   2           8
# 3   2539329        1             1                   2           8
# 4   2539329        1             1                   2           8
#
#    days_since_prior_order  new_customer  product_id  add_to_cart_order  \
# 0                     NaN          True         196                  1
# 1                     NaN          True       14084                  2
# 2                     NaN          True       12427                  3
# 3                     NaN          True       26088                  4
# 4                     NaN          True       26405                  5
#
#    reordered                             product_name  aisle_id  \
# 0          0                                     Soda        77
# ...

# %%
ords_prods_merge.head(100)
# Out:
#     order_id  user_id  order_number  orders_day_of_week  order_time  \
# 0    2539329        1             1                   2           8
# 1    2539329        1             1                   2           8
# 2    2539329        1             1                   2           8
# 3    2539329        1             1                   2           8
# 4    2539329        1             1                   2           8
# ..       ...      ...           ...                 ...         ...
# 95    738281        2             4                   2          10
# 96   1673511        2             5                   3          11
# 97   1673511        2             5                   3          11
# 98   1673511        2             5                   3          11
# 99   1673511        2             5                   3          11
#
#     days_since_prior_order  new_customer  product_id  add_to_cart_order  \
# 0                      NaN          True         196                  1
# ...

# %%
pd.options.display.max_rows = None

# %%
ords_prods_merge.head(100)
# checked and cleared cell output
# Out:
#     order_id  user_id  order_number  orders_day_of_week  order_time  \
# 0    2539329        1             1                   2           8
# 1    2539329        1             1                   2           8
# 2    2539329        1             1                   2           8
# 3    2539329        1             1                   2           8
# 4    2539329        1             1                   2           8
# 5    2398795        1             2                   3           7
# 6    2398795        1             2                   3           7
# 7    2398795        1             2                   3           7
# 8    2398795        1             2                   3           7
# 9    2398795        1             2                   3           7
# 10   2398795        1             2                   3           7
# 11    473747        1             3                   3          12
# 12    473747        1             3                   3          12
# ...

# %%
ords_prods_merge.loc[ords_prods_merge['max_order'] > 40, 'loyalty_flag'] = 'Loyal customer'

# %%
ords_prods_merge.loc[(ords_prods_merge['max_order'] <= 40) & (ords_prods_merge['max_order'] > 10), 'loyalty_flag'] = 'Regular customer'

# %%
ords_prods_merge.loc[ords_prods_merge['max_order'] <= 10, 'loyalty_flag'] = 'New customer'

# %%
ords_prods_merge['loyalty_flag']. value_counts(dropna=False)
# Out:
# loyalty_flag
# Regular customer    15876776
# Loyal customer      10284093
# New customer         6243990
# Name: count, dtype: int64

# %%
ords_prods_merge[['user_id', 'loyalty_flag', 'order_number']].head(60)
# Out:
#     user_id      loyalty_flag  order_number
# 0         1      New customer             1
# 1         1      New customer             1
# 2         1      New customer             1
# 3         1      New customer             1
# 4         1      New customer             1
# 5         1      New customer             2
# 6         1      New customer             2
# 7         1      New customer             2
# 8         1      New customer             2
# 9         1      New customer             2
# 10        1      New customer             2
# 11        1      New customer             3
# 12        1      New customer             3
# 13        1      New customer             3
# 14        1      New customer             3
# 15        1      New customer             3
# 16        1      New customer             4
# 17        1      New customer             4
# 18        1      New customer             4
# 19        1      New customer             4
# ...

# %% [markdown]
# # 5.check the basic statistics of the product prices for each loyalty category (Loyal Customer, Regular Customer, and New Customer)

# %%
ords_prods_merge.groupby('loyalty_flag').agg({'prices': ['mean', 'min', 'max']})
# Out:
#                      prices
#                        mean  min      max
# loyalty_flag
# Loyal customer    10.386335  1.0  99999.0
# New customer      13.294669  1.0  99999.0
# Regular customer  12.495717  1.0  99999.0

# %%
#option 2 
ords_prods_merge.groupby('loyalty_flag')['prices'].describe()
# Out:
#                        count       mean         std  min  25%  50%   75%  \
# loyalty_flag
# Loyal customer    10284093.0  10.386333  327.981293  1.0  4.2  7.4  11.2
# New customer       6243990.0  13.294672  597.521545  1.0  4.2  7.4  11.3
# Regular customer  15876776.0  12.495719  539.679504  1.0  4.2  7.4  11.3
#
#                       max
# loyalty_flag
# Loyal customer    99999.0
# New customer      99999.0
# Regular customer  99999.0

# %% [markdown]
#  On average, loyal customers tend to purchase cheaper products than both new and regular customers

# %% [markdown]
# # 6.Create a spending flag for each user based on the average price across all their orders

# %%
# 6.Create a spending flag for each user based on the average price across all their orders 
ords_prods_merge['mean_prices'] = ords_prods_merge.groupby(['user_id'])['prices'].transform('mean')

# %%
ords_prods_merge.head()
# Out:
#    order_id  user_id  order_number  orders_day_of_week  order_time  \
# 0   2539329        1             1                   2           8
# 1   2539329        1             1                   2           8
# 2   2539329        1             1                   2           8
# 3   2539329        1             1                   2           8
# 4   2539329        1             1                   2           8
#
#    days_since_prior_order  new_customer  product_id  add_to_cart_order  \
# 0                     NaN          True         196                  1
# 1                     NaN          True       14084                  2
# 2                     NaN          True       12427                  3
# 3                     NaN          True       26088                  4
# 4                     NaN          True       26405                  5
#
#    reordered                             product_name  aisle_id  \
# 0          0                                     Soda        77
# ...

# %%
ords_prods_merge.loc[ords_prods_merge['mean_prices'] <10, 'spending_flag'] = 'Low spender'

# %%
ords_prods_merge.loc[ords_prods_merge['mean_prices'] >=10, 'spending_flag'] = 'High spender'

# %%
ords_prods_merge['spending_flag']. value_counts(dropna=False)
# Out:
# spending_flag
# Low spender     31770614
# High spender      634245
# Name: count, dtype: int64

# %%
ords_prods_merge[['user_id', 'spending_flag']].head(60)
# Out:
#     user_id spending_flag
# 0         1   Low spender
# 1         1   Low spender
# 2         1   Low spender
# 3         1   Low spender
# 4         1   Low spender
# 5         1   Low spender
# 6         1   Low spender
# 7         1   Low spender
# 8         1   Low spender
# 9         1   Low spender
# 10        1   Low spender
# 11        1   Low spender
# 12        1   Low spender
# 13        1   Low spender
# 14        1   Low spender
# 15        1   Low spender
# 16        1   Low spender
# 17        1   Low spender
# 18        1   Low spender
# 19        1   Low spender
# 20        1   Low spender
# 21        1   Low spender
# 22        1   Low spender
# 23        1   Low spender
# 24        1   Low spender
# 25        1   Low spender
# 26        1   Low spender
# 27        1   Low spender
# 28        1   Low spender
# 29        1   Low spender
# 30        1   Low spender
# 31        1   Low spender
# 32        1   Low spender
# 33        1   Low spender
# ...

# %% [markdown]
# # 7. Create an order frequency flag that marks the regularity of a user’s ordering behavior according to the median in the “days_since_prior_order” column.

# %%
ords_prods_merge['median_days'] = ords_prods_merge.groupby(['user_id'])['days_since_prior_order'].transform('median')

# %%
ords_prods_merge.head()
# Out:
#    order_id  user_id  order_number  orders_day_of_week  order_time  \
# 0   2539329        1             1                   2           8
# 1   2539329        1             1                   2           8
# 2   2539329        1             1                   2           8
# 3   2539329        1             1                   2           8
# 4   2539329        1             1                   2           8
#
#    days_since_prior_order  new_customer  product_id  add_to_cart_order  \
# 0                     NaN          True         196                  1
# 1                     NaN          True       14084                  2
# 2                     NaN          True       12427                  3
# 3                     NaN          True       26088                  4
# 4                     NaN          True       26405                  5
#
#    reordered  ... department_id  prices    price_range_loc     busiest_day  \
# ...

# %%
ords_prods_merge.loc[ords_prods_merge['median_days'] > 20, 'frequency_flag'] = 'Non-frequent customer'

# %%
ords_prods_merge.loc[(ords_prods_merge['median_days'] <= 20) & (ords_prods_merge['median_days'] > 10), 'frequency_flag'] = 'Regular customer'

# %%
ords_prods_merge.loc[ords_prods_merge['median_days'] <= 10 , 'frequency_flag'] = 'Frequent customer'

# %%
ords_prods_merge['frequency_flag']. value_counts(dropna=False)
# Out:
# frequency_flag
# Frequent customer        21559853
# Regular customer          7208564
# Non-frequent customer     3636437
# NaN                             5
# Name: count, dtype: int64

# %%
# checking NaN values --- looks like it's a new customer and doesn't have purchasing history in the books yet.
ords_prods_merge[ords_prods_merge['frequency_flag'].isna()]
# Out:
#           order_id  user_id  order_number  orders_day_of_week  order_time  \
# 25156870    895835   159838             1                   0          17
# 25156871    895835   159838             1                   0          17
# 25156872    895835   159838             1                   0          17
# 25156873    895835   159838             1                   0          17
# 25156874    895835   159838             1                   0          17
#
#           days_since_prior_order  new_customer  product_id  add_to_cart_order  \
# 25156870                     NaN          True       22198                  1
# 25156871                     NaN          True       23695                  2
# 25156872                     NaN          True       10749                  3
# 25156873                     NaN          True       21334                  5
# 25156874                     NaN          True       33401                  6
#
# ...

# %%
ords_prods_merge[['user_id', 'frequency_flag','days_since_prior_order','median_days']].head(60)
# Out:
#     user_id         frequency_flag  days_since_prior_order  median_days
# 0         1  Non-frequent customer                     NaN         20.5
# 1         1  Non-frequent customer                     NaN         20.5
# 2         1  Non-frequent customer                     NaN         20.5
# 3         1  Non-frequent customer                     NaN         20.5
# 4         1  Non-frequent customer                     NaN         20.5
# 5         1  Non-frequent customer                    15.0         20.5
# 6         1  Non-frequent customer                    15.0         20.5
# 7         1  Non-frequent customer                    15.0         20.5
# 8         1  Non-frequent customer                    15.0         20.5
# 9         1  Non-frequent customer                    15.0         20.5
# 10        1  Non-frequent customer                    15.0         20.5
# 11        1  Non-frequent customer                    21.0         20.5
# ...

# %%
# Export data to pkl
ords_prods_merge.to_pickle(os.path.join(path, '02 Data','Prepared Data', 'df_ords_prods_merge_4.8.pkl'))

# %%
ords_prods_merge.groupby(['loyalty_flag']).user_id.nunique()
# Out:
# loyalty_flag
# Loyal customer       17017
# New customer        112328
# Regular customer     76864
# Name: user_id, dtype: int64

# %%
# make the outliners as missing values
ords_prods_merge.loc[ords_prods_merge['prices'] >100, 'prices'] = np.nan

# %%
ords_prods_merge['prices'].max()
# Out:
# 25.0

# %%
# Export data to pkl
ords_prods_merge.to_pickle(os.path.join(path, '02 Data','Prepared Data', 'df_ords_prods_merge_final.pkl'))
